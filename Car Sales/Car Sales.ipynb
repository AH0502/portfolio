# %%
# Import relevant libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

sns.set_theme()

# %%
# Load the data.
data = pd.read_csv('car_sales.csv')

# %%
# Inspect the data.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4345 entries, 0 to 4344
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         4345 non-null   object
#  1   Price         4173 non-null   float64
#  2   Body          4345 non-null   object
#  3   Mileage       4345 non-null   int64
#  4   EngineV       4195 non-null   float64
#  5   Engine Type   4345 non-null   object
#  6   Registration  4345 non-null   object
#  7   Year          4345 non-null   int64
#  8   Model         4345 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 305.6+ KB

# %%
data.head()
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW   4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz   7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz  13300.0      sedan      358      5.0         Gas
# 3           Audi  23000.0  crossover      240      4.2      Petrol
# 4         Toyota  18300.0  crossover      120      2.0      Petrol
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4

# %%
data.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year    Model
# count         4345         4345  4345.000000     4345
# ...

# %%
# let's drop the 'Model' column.
data_cleaned = data.drop(['Model'],axis=1)

# %%
data_cleaned.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4345         4345  4345.000000
# unique           4            2          NaN
# ...

# %%
# We now need to deal with the missing values
data_cleaned.isnull().sum()
# Out:
# Brand             0
# Price           172
# Body              0
# Mileage           0
# EngineV         150
# Engine Type       0
# Registration      0
# Year              0
# dtype: int64

# %%
# if we remove > 5% we are safe
data_no_mv = data_cleaned.dropna(axis=0)
print(data_no_mv)
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4339         Toyota   17900.0      sedan       35      1.6      Petrol
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %%
# Let's visualize PDF
data_no_mv.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4025    4025.000000   4025  4025.000000  4025.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1534          NaN          NaN
# mean           NaN   19552.308065    NaN   163.572174     2.764586
# std            NaN   25815.734988    NaN   103.394703     4.935941
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    90.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21900.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4025         4025  4025.000000
# unique           4            2          NaN
# ...

# %%
sns.distplot(data_no_mv['Price'])
# Out:
# /var/folders/gq/vf77ry2j1cb_0bd82nsb27hc0000gn/T/ipykernel_23129/216991009.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_mv['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# We will remove the top 1% 
q = data_no_mv['Price'].quantile(.99)
data_1 = data_no_mv[data_no_mv['Price'] < q]

# %%
# Now let's visualize
sns.distplot(data_1['Price'])
# Out:
# /var/folders/gq/vf77ry2j1cb_0bd82nsb27hc0000gn/T/ipykernel_23129/997928529.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
data_1.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3984    3984.000000   3984  3984.000000  3984.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1528          NaN          NaN
# mean           NaN   17837.117460    NaN   165.116466     2.743770
# std            NaN   18976.268315    NaN   102.766126     4.956057
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6980.000000    NaN    93.000000     1.800000
# 50%            NaN   11400.000000    NaN   160.000000     2.200000
# 75%            NaN   21000.000000    NaN   230.000000     3.000000
# max            NaN  129222.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         3984         3984  3984.000000
# unique           4            2          NaN
# ...

# %%
sns.distplot(data_1['Mileage'])
# Out:
# /var/folders/gq/vf77ry2j1cb_0bd82nsb27hc0000gn/T/ipykernel_23129/1547815769.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['Mileage'])
# <Axes: xlabel='Mileage', ylabel='Density'>

# %%
# Let's remove the outliers
q = data_1['Mileage'].quantile(.99)
data_2 = data_1[data_1['Mileage'] < q]
sns.distplot(data_2['Mileage'])
# Out:
# /var/folders/gq/vf77ry2j1cb_0bd82nsb27hc0000gn/T/ipykernel_23129/2101371604.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2['Mileage'])
# <Axes: xlabel='Mileage', ylabel='Density'>

# %%
data_2.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3944    3944.000000   3944  3944.000000  3944.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           867            NaN   1511          NaN          NaN
# mean           NaN   17933.880822    NaN   161.484026     2.747612
# std            NaN   19008.212025    NaN    96.027108     4.980406
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    7000.000000    NaN    92.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21376.250000    NaN   230.000000     3.000000
# max            NaN  129222.000000    NaN   435.000000    99.990000
#
#        Engine Type Registration         Year
# count         3944         3944  3944.000000
# unique           4            2          NaN
# ...

# %%
sns.distplot(data_2['EngineV'])
# Out:
# /var/folders/gq/vf77ry2j1cb_0bd82nsb27hc0000gn/T/ipykernel_23129/2389813043.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2['EngineV'])
# <Axes: xlabel='EngineV', ylabel='Density'>

# %%
# We will remove all rows that have values > 6.5
data_3 = data_2[data_2['EngineV'] <= 6.5]

# %%
sns.distplot(data_3['EngineV'])
# Out:
# /var/folders/gq/vf77ry2j1cb_0bd82nsb27hc0000gn/T/ipykernel_23129/1902427236.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3['EngineV'])
# <Axes: xlabel='EngineV', ylabel='Density'>

# %%
data_3.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3922    3922.000000   3922  3922.000000  3922.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           862            NaN   1500          NaN          NaN
# mean           NaN   17992.886272    NaN   161.279449     2.444531
# std            NaN   19041.283610    NaN    96.056020     0.948292
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    7000.000000    NaN    92.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21500.000000    NaN   229.000000     3.000000
# max            NaN  129222.000000    NaN   435.000000     6.500000
#
#        Engine Type Registration         Year
# count         3922         3922  3922.000000
# unique           4            2          NaN
# ...

# %%
sns.distplot(data_3['Year'])
# Out:
# /var/folders/gq/vf77ry2j1cb_0bd82nsb27hc0000gn/T/ipykernel_23129/2525852583.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3['Year'])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
# Let's remove 1st percetile
q = data_3['Year'].quantile(.1)
data_4 = data_3[data_3['Year'] > q]

# %%
sns.distplot(data_4['Year'])
# Out:
# /var/folders/gq/vf77ry2j1cb_0bd82nsb27hc0000gn/T/ipykernel_23129/2748958191.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_4['Year'])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
# Now let's reset the index
data_cleaned = data_4.reset_index(drop=True)
data_cleaned.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3460    3460.000000   3460  3460.000000  3460.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           762            NaN   1208          NaN          NaN
# mean           NaN   19802.694757    NaN   147.936127     2.465220
# std            NaN   19541.538728    NaN    86.679171     0.974286
# min            NaN    1200.000000    NaN     0.000000     0.600000
# 25%            NaN    8400.000000    NaN    85.000000     1.800000
# 50%            NaN   12850.000000    NaN   148.000000     2.200000
# 75%            NaN   23500.000000    NaN   205.000000     3.000000
# max            NaN  129222.000000    NaN   427.000000     6.500000
#
#        Engine Type Registration         Year
# count         3460         3460  3460.000000
# unique           4            2          NaN
# ...

# %%
# Preprocessing done for now.
